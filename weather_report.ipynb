# %% [markdown]
# Weather Report
# this is a project report on weather dataset analysis

# %%
import pandas as pd

# %%
data=pd.read_csv("weather_data.csv")

# %%
print(data.head())
# Out:
#        Location            Date_Time  Temperature_C  Humidity_pct  \
# 0     San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1     San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2     San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3  Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4   San Antonio  2024-04-29 13:23:51      39.808213     72.899908
#
#    Precipitation_mm  Wind_Speed_kmh
# 0          4.020119        8.233540
# 1          9.111623       27.715161
# 2          4.607511       28.732951
# 3          3.183720       26.367303
# 4          9.598282       29.898622

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#             Location            Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1          San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2          San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3       Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4        San Antonio  2024-04-29 13:23:51      39.808213     72.899908
# ...              ...                  ...            ...           ...
# 999995        Dallas  2024-01-01 20:29:48      23.416877     37.705024
# 999996   San Antonio  2024-01-20 15:59:48       6.759080     40.731036
# 999997      New York  2024-04-14 08:30:09      15.664465     62.201884
# 999998       Chicago  2024-05-12 20:10:43      18.999994     63.703245
# 999999      New York  2024-04-16 16:11:52      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119        8.233540
# ...

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of             Location            Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1          San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2          San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3       Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4        San Antonio  2024-04-29 13:23:51      39.808213     72.899908
# ...              ...                  ...            ...           ...
# 999995        Dallas  2024-01-01 20:29:48      23.416877     37.705024
# 999996   San Antonio  2024-01-20 15:59:48       6.759080     40.731036
# 999997      New York  2024-04-14 08:30:09      15.664465     62.201884
# 999998       Chicago  2024-05-12 20:10:43      18.999994     63.703245
# 999999      New York  2024-04-16 16:11:52      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119        8.233540
# ...

# %%
print(data.describe)
# Out:
# <bound method NDFrame.describe of             Location            Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1          San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2          San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3       Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4        San Antonio  2024-04-29 13:23:51      39.808213     72.899908
# ...              ...                  ...            ...           ...
# 999995        Dallas  2024-01-01 20:29:48      23.416877     37.705024
# 999996   San Antonio  2024-01-20 15:59:48       6.759080     40.731036
# 999997      New York  2024-04-14 08:30:09      15.664465     62.201884
# 999998       Chicago  2024-05-12 20:10:43      18.999994     63.703245
# 999999      New York  2024-04-16 16:11:52      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh
# ...

# %%
print(data.isnull)
# Out:
# <bound method DataFrame.isnull of             Location            Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1          San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2          San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3       Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4        San Antonio  2024-04-29 13:23:51      39.808213     72.899908
# ...              ...                  ...            ...           ...
# 999995        Dallas  2024-01-01 20:29:48      23.416877     37.705024
# 999996   San Antonio  2024-01-20 15:59:48       6.759080     40.731036
# 999997      New York  2024-04-14 08:30:09      15.664465     62.201884
# 999998       Chicago  2024-05-12 20:10:43      18.999994     63.703245
# 999999      New York  2024-04-16 16:11:52      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh
# ...

# %%
data['Date_Time']=pd.to_datetime(data['Date_Time'])

# %%
data
# Out:
#             Location           Date_Time  Temperature_C  Humidity_pct  \
# 0          San Diego 2024-01-14 21:12:46      10.683001     41.195754
# 1          San Diego 2024-05-17 15:22:10       8.734140     58.319107
# 2          San Diego 2024-05-11 09:30:59      11.632436     38.820175
# 3       Philadelphia 2024-02-26 17:32:39      -8.628976     54.074474
# 4        San Antonio 2024-04-29 13:23:51      39.808213     72.899908
# ...              ...                 ...            ...           ...
# 999995        Dallas 2024-01-01 20:29:48      23.416877     37.705024
# 999996   San Antonio 2024-01-20 15:59:48       6.759080     40.731036
# 999997      New York 2024-04-14 08:30:09      15.664465     62.201884
# 999998       Chicago 2024-05-12 20:10:43      18.999994     63.703245
# 999999      New York 2024-04-16 16:11:52      10.725351     43.804584
#
#         Precipitation_mm  Wind_Speed_kmh
# 0               4.020119        8.233540
# 1               9.111623       27.715161
# ...

# %%
import numpy as np

# %%
data['month']=data['Date_Time'].dt.month

# %%
monthly_avg_temp=data.groupby('month')['Temperature_C'].mean()

# %%
monthly_avg_temp
# Out:
# month
# 1    14.446461
# 2    14.502081
# 3    15.005691
# 4    15.001603
# 5    15.042793
# Name: Temperature_C, dtype: float64

# %%
hottest_day=data.loc[data["Temperature_C"].idxmax()]
hottest_day
# Out:
# Location                       New York
# Date_Time           2024-05-16 14:31:50
# Temperature_C                 39.999801
# Humidity_pct                  35.418345
# Precipitation_mm               6.574819
# Wind_Speed_kmh                20.988972
# month                                 5
# Name: 899115, dtype: object

# %%
coldest_day=data.loc[data["Temperature_C"].idxmin()]
coldest_day
# Out:
# Location                        Phoenix
# Date_Time           2024-01-12 20:20:14
# Temperature_C                -19.969311
# Humidity_pct                  52.217649
# Precipitation_mm               0.554449
# Wind_Speed_kmh                 21.77262
# month                                 1
# Name: 360894, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(monthly_avg_temp.index,monthly_avg_temp.values,marker='o', color='green')
plt.title("Monthly Average Temperature Trend")
plt.xlabel('Month')
plt.ylabel('Average Temperature')
plt.grid()
plt.show()

# %%
monthly_avg_rainfall=data.groupby('month')['Precipitation_mm'].mean()

# %%
plt.plot(monthly_avg_rainfall.index,monthly_avg_rainfall.values,marker='o', color='blue')
plt.title("Monthly Average Rainfall Trend")
plt.xlabel('Month')
plt.ylabel('Average Precipitation')
plt.grid()
plt.show()

# %%
monthly_avg_humidity=data.groupby('month')['Humidity_pct'].mean()

# %%
plt.plot(monthly_avg_humidity.index,monthly_avg_humidity.values,marker='o', color='red')
plt.title("Monthly Average Humidity Trend")
plt.xlabel('Month')
plt.ylabel('Average Humidity')
plt.grid()
plt.show()

# %%
monthly_temp_varience=data.groupby('month')['Temperature_C'].var()

# %%
monthly_temp_varience.plot(kind='bar',color='orange',figsize=(10,5))
plt.title('Monthly Temperature Varience')
plt.xlabel('Month')
plt.ylabel('Temperature Varience')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(data['Temperature_C'],kde=True,color='purple',bins=15)
plt.title('Temperature Distribution')
plt.xlabel('Temperature')
plt.ylabel('Frequncy')
plt.show()

# %%
sns.histplot(data['Precipitation_mm'],kde=True,color='blue',bins=15)
plt.title('Rainfall Distribution')
plt.xlabel('Precipitation')
plt.ylabel('Frequncy')
plt.show()
